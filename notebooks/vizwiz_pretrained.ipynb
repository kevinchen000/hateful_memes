# %% [markdown]
# ## Coco Pretraining

# %% [markdown]
# ## Libraries and Setup

# %%
import os
import yaml
import io

# %%
### Mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Local MMF Setup
# - Branched and updated mmf repo clone
# - Setting data dir to persisted location on google drive

# %%
# %cd '/content/drive/MyDrive/mmf-main'
# %env MMF_DATA_DIR=../hateful_memes/
# %env MMF_LOG_DIR=../hateful_memes/
# %env MMF_REPORT_DIR=../hateful_memes/
# %env MMF_TENSORBOARD_LOGDIR=../hateful_memes/
# %env MMF_WANDB_LOGDIR=../hateful_memes/

# !pip install --editable .
# Out:
# /content/drive/MyDrive/mmf-main
# env: MMF_DATA_DIR=../hateful_memes/
# env: MMF_LOG_DIR=../hateful_memes/
# env: MMF_REPORT_DIR=../hateful_memes/
# env: MMF_TENSORBOARD_LOGDIR=../hateful_memes/
# env: MMF_WANDB_LOGDIR=../hateful_memes/
# Obtaining file:///content/drive/MyDrive/mmf-main
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for mmf (pyproject.toml) ... done
#   Created wheel for mmf: filename=mmf-1.0.0rc12-0.editable-cp310-cp310-linux_x86_64.whl size=10743 sha256=a90300d1629b6235571f57741e608cce2c8701ef36b256d9e40d5dec06d07d98
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vjk4g7ul/wheels/e3/9f/fc/d49548515b10b7b3c02969460b19f70eb734152532b702074e
# Successfully built mmf
# ...
#   Attempting uninstall: mmf
#     Found existing installation: mmf 1.0.0rc12
# ...

# %%
### Import General Modules, 3min
from mmf.common.registry import registry
from mmf.models.mmbt import MMBT
from mmf.utils.build import build_dataset
from mmf.utils.env import setup_imports
import matplotlib.pyplot as plt
from PIL import Image
import torch

from mmf.common.registry import registry
from mmf.datasets.base_dataset_builder import BaseDatasetBuilder
from mmf.datasets.mmf_dataset_builder import MMFDatasetBuilder

### Import Modules for Fusion Model
# All model using MMF need to inherit BaseModel
from mmf.models.base_model import BaseModel
# Builder methods for image encoder and classifier
from mmf.utils.build import build_classifier_layer, build_image_encoder,build_text_encoder

setup_imports()
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# /usr/local/lib/python3.10/dist-packages/transformers/deepspeed.py:23: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(

# %% [markdown]
# ## Download COCO

# %%
# %cd '/content/drive/MyDrive/hateful_memes/'
# !chmod +x 'coco_download.sh'
# !bash coco_download.sh

# %%
dataset = build_dataset("nlvr2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-4b746563348c> in <cell line: 1>()
# ----> 1 dataset = build_dataset("nlvr2")
#
# /content/drive/MyDrive/mmf-main/mmf/utils/build.py in build_dataset(dataset_key, config, dataset_type)
#     198
#     199     datamodule_instance.build_dataset(config)
# --> 200     dataset = datamodule_instance.load_dataset(config, dataset_type)
#     201     if hasattr(datamodule_instance, "update_registry_for_model"):
#     202         datamodule_instance.update_registry_for_model(config)
#
# /content/drive/MyDrive/mmf-main/mmf/datasets/base_dataset_builder.py in load_dataset(self, config, dataset_type, *args, **kwargs)
#     161             DO NOT OVERRIDE in child class. Instead override ``load``.
#     162         """
# --> 163         dataset = self.load(config, dataset_type, *args, **kwargs)
# ...

# %% [markdown]
# ## Configure Dataset Config

# %%
dataset_config_path = 'mmf/configs/datasets/coco/detection.yaml'
with io.open(dataset_config_path, 'r') as f:
    dataset_config = yaml.safe_load(f)

# %%
# !mmf_run \
config=projects/visual_bert/configs/vizwiz/defaults.yaml \
model=visual_bert \
dataset=vizwiz \
run_type=train_val
# Out:
# Streaming output truncated to the last 5000 lines.
#     "LABEL_3275": 3275,
#     "LABEL_3276": 3276,
#     "LABEL_3277": 3277,
#     "LABEL_3278": 3278,
#     "LABEL_3279": 3279,
#     "LABEL_328": 328,
#     "LABEL_3280": 3280,
#     "LABEL_3281": 3281,
#     "LABEL_3282": 3282,
#     "LABEL_3283": 3283,
#     "LABEL_3284": 3284,
#     "LABEL_3285": 3285,
#     "LABEL_3286": 3286,
#     "LABEL_3287": 3287,
#     "LABEL_3288": 3288,
#     "LABEL_3289": 3289,
#     "LABEL_329": 329,
#     "LABEL_3290": 3290,
#     "LABEL_3291": 3291,
#     "LABEL_3292": 3292,
#     "LABEL_3293": 3293,
#     "LABEL_3294": 3294,
#     "LABEL_3295": 3295,
#     "LABEL_3296": 3296,
#     "LABEL_3297": 3297,
#     "LABEL_3298": 3298,
#     "LABEL_3299": 3299,
#     "LABEL_33": 33,
#     "LABEL_330": 330,
#     "LABEL_3300": 3300,
#     "LABEL_3301": 3301,
#     "LABEL_3302": 3302,
#     "LABEL_3303": 3303,
#     "LABEL_3304": 3304,
#     "LABEL_3305": 3305,
#     "LABEL_3306": 3306,
# ...
